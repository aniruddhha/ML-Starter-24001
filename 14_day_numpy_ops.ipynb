# %%
import numpy as np

# %%
data = np.array([1, 2])
ones = np.ones(2, dtype = int)

# %%
data + ones
# Out:
# array([0, 1])

# %%
data.shape
# Out:
# (2,)

# %%
data - ones
# Out:
# array([0, 1])

# %%
data * ones
# Out:
# array([1, 2])

# %%
data / ones
# Out:
# array([1., 2.])

# %%
a = np.array([1, 2, 3, 4])

# %%
a.sum()
# Out:
# 10

# %%
b = np.array([[-1, 2], [3, 2]])

# %%
b.sum(axis = 1)
# Out:
# array([1, 5])

# %%
data = np.array([1.0, 2.0])
data * 1.6
# Out:
# array([1.6, 3.2])

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])
b = np.array([7, 8, 8])

c = a + b
print(c)
# Out:
# [[ 8 10 11]
#  [11 13 14]]

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])
b = np.array([[1], [2]])

c = a * b

print(c)
# Out:
# [[ 1  2  3]
#  [ 8 10 12]]

# %%
# array with static values with shape 3 x 4 with float values between 0 to 1, dont use random function

a = np.array([[0.45053314, 0.17296777, 0.34376245, 0.5510652],
              [0.54627315, 0.05093587, 0.40067661, 0.55645993],
              [0.12697628, 0.82485143, 0.26590556, 0.56917101]])

# %%
(a.sum(), a.min(), a.max() )
# Out:
# (4.8595784, 0.05093587, 0.82485143)
