# %%
# emp_name: str = 'abc'
emp_name = 'abc' # string
emp_name = 12 # int

# %%
emp_age: int = 10
emp_age = 'abc'

# %%
def add_three_num(n1: int, n2: int, n3: int) -> int:
  return n1 + n2 + n3

# %%
print(add_three_num('1', '2', '3'))
# Out:
# Addition is 123

# %%
print(add_three_num('abc', 'lmn', 10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-14ca9bc41083> in <cell line: 1>()
# ----> 1 print(add_three_num('abc', 'lmn', 10))
#
# <ipython-input-8-8c07bceeae7b> in add_three_num(n1, n2, n3)
#       1 def add_three_num(n1: int, n2: int, n3: int) -> int:
# ----> 2   return f'Addition is {n1 + n2 + n3}'
#
# TypeError: can only concatenate str (not "int") to str

# %%
fn_lmd = lambda a: int, b: int:  a + b
# Out:
#   File "<ipython-input-14-e17907aaa1d2>", line 1
#     fn_lmd = lambda a: int, b: int:  a + b
#                              ^
# SyntaxError: invalid syntax

# %%
fn = lambda a, b: a + b

# %%
def connect(url: str) -> bool:
  return url == 'abc'

# %%
# hence from now whatever code we will write, that should have type hints.
