# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 7.1 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 15.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
# !git clone https://github.com/laxmimerit/dog-cat-full-dataset.git /content/gdrive/MyDrive/colab_images
# Out:
# Cloning into '/content/gdrive/MyDrive/colab_images'...
# remote: Enumerating objects: 25033, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 25033 (delta 0), reused 4 (delta 0), pack-reused 25027 (from 1)
# Receiving objects: 100% (25033/25033), 541.85 MiB | 23.12 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Updating files: 100% (24990/24990), done.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from skimage.feature import hog
from skimage import io, transform
import os
import optuna
import pickle

# %%
def load_images(path, label):
    images = []
    labels = []
    for filename in os.listdir(path):
        try:
            img = io.imread(os.path.join(path, filename))
            img = transform.resize(img, (64, 64))
            images.append(img)
            labels.append(label)
        except Exception as e:
            print(e)
    return np.array(images), np.array(labels)

# %%
# Load datasets
cats_path = 'small/cats'
dogs_path = 'small/dogs'

cat_images, cat_labels = load_images(cats_path, label=0)
dog_images, dog_labels = load_images(dogs_path, label=1)

# %%
X = np.concatenate((cat_images, dog_images), axis=0)
y = np.concatenate((cat_labels, dog_labels), axis=0)

# %%
# Extract HOG features
def extract_hog_features(images):
    features = []
    for image in images:
        feature = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), channel_axis = -1)
        features.append(feature)
    return np.array(features)

# %%
X_hog = extract_hog_features(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_hog, y, test_size=0.2, random_state=42)

# %%
# Define the Optuna objective function
def objective(trial):
    model_type = trial.suggest_categorical("model_type", ["logistic_regression", "svm"])

    if model_type == "logistic_regression":
        C = trial.suggest_float("C", 1e-3, 1e3, log=True)
        model = LogisticRegression(C=C, max_iter=1000, random_state=42)
    elif model_type == "svm":
        C = trial.suggest_float("C", 1e-3, 1e3, log=True)
        kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly"])
        model = SVC(C=C, kernel=kernel, random_state=42)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    return accuracy_score(y_test, y_pred)

# %%
# Run Optuna study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2024-12-15 10:37:52,413] A new study created in memory with name: no-name-f3e653d5-39a0-46b6-b81a-35eb24f99232
# [I 2024-12-15 10:37:54,196] Trial 0 finished with value: 0.734 and parameters: {'model_type': 'logistic_regression', 'C': 0.13006378088999365}. Best is trial 0 with value: 0.734.
# [I 2024-12-15 10:37:54,575] Trial 1 finished with value: 0.72 and parameters: {'model_type': 'logistic_regression', 'C': 0.001250326807216914}. Best is trial 0 with value: 0.734.
# [I 2024-12-15 10:37:55,996] Trial 2 finished with value: 0.725 and parameters: {'model_type': 'logistic_regression', 'C': 0.26602991145695176}. Best is trial 0 with value: 0.734.
# [I 2024-12-15 10:38:25,725] Trial 3 finished with value: 0.682 and parameters: {'model_type': 'svm', 'C': 2.894870808206561, 'kernel': 'linear'}. Best is trial 0 with value: 0.734.
# [I 2024-12-15 10:38:26,408] Trial 4 finished with value: 0.732 and parameters: {'model_type': 'logistic_regression', 'C': 0.15473646661462342}. Best is trial 0 with value: 0.734.
# [I 2024-12-15 10:38:26,583] Trial 5 finished with value: 0.72 and parameters: {'model_type': 'logistic_regression', 'C': 0.0013764155993273436}. Best is trial 0 with value: 0.734.
# [I 2024-12-15 10:38:28,348] Trial 6 finished with value: 0.7 and parameters: {'model_type': 'logistic_regression', 'C': 4.165895032417095}. Best is trial 0 with value: 0.734.
# [I 2024-12-15 10:38:55,263] Trial 7 finished with value: 0.741 and parameters: {'model_type': 'svm', 'C': 202.3750163686381, 'kernel': 'poly'}. Best is trial 7 with value: 0.741.
# [I 2024-12-15 10:38:55,513] Trial 8 finished with value: 0.717 and parameters: {'model_type': 'logistic_regression', 'C': 0.0031590004000961423}. Best is trial 7 with value: 0.741.
# [I 2024-12-15 10:38:55,858] Trial 9 finished with value: 0.732 and parameters: {'model_type': 'logistic_regression', 'C': 0.029993625397044626}. Best is trial 7 with value: 0.741.
# [I 2024-12-15 10:39:30,258] Trial 10 finished with value: 0.741 and parameters: {'model_type': 'svm', 'C': 405.8235612353397, 'kernel': 'poly'}. Best is trial 7 with value: 0.741.
# [I 2024-12-15 10:39:57,112] Trial 11 finished with value: 0.741 and parameters: {'model_type': 'svm', 'C': 665.8640293241059, 'kernel': 'poly'}. Best is trial 7 with value: 0.741.
# [I 2024-12-15 10:40:24,157] Trial 12 finished with value: 0.741 and parameters: {'model_type': 'svm', 'C': 696.0833350384781, 'kernel': 'poly'}. Best is trial 7 with value: 0.741.
# [I 2024-12-15 10:40:53,523] Trial 13 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 47.00299218548751, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:41:22,851] Trial 14 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 36.265821725265006, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:41:52,519] Trial 15 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 30.595579987757535, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:42:22,291] Trial 16 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 29.801410616107535, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:42:52,340] Trial 17 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 47.05563583957902, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:43:22,287] Trial 18 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 5.903220139276953, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:43:51,967] Trial 19 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 80.12960691665558, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:44:34,436] Trial 20 finished with value: 0.668 and parameters: {'model_type': 'svm', 'C': 9.544972903888508, 'kernel': 'linear'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:45:04,460] Trial 21 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 24.118863444398702, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:45:34,675] Trial 22 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 125.58678430338605, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:46:01,914] Trial 23 finished with value: 0.74 and parameters: {'model_type': 'svm', 'C': 0.8847437185732034, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:46:31,889] Trial 24 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 16.468645378553756, 'kernel': 'rbf'}. Best is trial 13 with value: 0.751.
# [I 2024-12-15 10:47:00,285] Trial 25 finished with value: 0.752 and parameters: {'model_type': 'svm', 'C': 1.710462130877609, 'kernel': 'rbf'}. Best is trial 25 with value: 0.752.
# [I 2024-12-15 10:47:28,265] Trial 26 finished with value: 0.754 and parameters: {'model_type': 'svm', 'C': 1.5982342917828098, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:47:51,331] Trial 27 finished with value: 0.702 and parameters: {'model_type': 'svm', 'C': 1.2448842601416672, 'kernel': 'linear'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:48:21,594] Trial 28 finished with value: 0.742 and parameters: {'model_type': 'svm', 'C': 0.7517526560536606, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:48:53,910] Trial 29 finished with value: 0.716 and parameters: {'model_type': 'svm', 'C': 0.03954455261612235, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:49:23,364] Trial 30 finished with value: 0.724 and parameters: {'model_type': 'svm', 'C': 0.04659163120992531, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:49:52,158] Trial 31 finished with value: 0.754 and parameters: {'model_type': 'svm', 'C': 2.3541489121654213, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:50:20,978] Trial 32 finished with value: 0.754 and parameters: {'model_type': 'svm', 'C': 1.9914244730744954, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:50:45,885] Trial 33 finished with value: 0.736 and parameters: {'model_type': 'svm', 'C': 0.43070778661555464, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:51:14,050] Trial 34 finished with value: 0.754 and parameters: {'model_type': 'svm', 'C': 1.7734387768410564, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:51:34,077] Trial 35 finished with value: 0.716 and parameters: {'model_type': 'svm', 'C': 0.3609622272365147, 'kernel': 'linear'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:51:35,287] Trial 36 finished with value: 0.711 and parameters: {'model_type': 'logistic_regression', 'C': 2.381861195806986}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:52:03,406] Trial 37 finished with value: 0.724 and parameters: {'model_type': 'svm', 'C': 0.0833657188863945, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:52:05,820] Trial 38 finished with value: 0.69 and parameters: {'model_type': 'logistic_regression', 'C': 7.794241561933828}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:52:35,746] Trial 39 finished with value: 0.752 and parameters: {'model_type': 'svm', 'C': 3.2934404394112375, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:52:36,316] Trial 40 finished with value: 0.728 and parameters: {'model_type': 'logistic_regression', 'C': 0.1689628217674117}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:53:04,179] Trial 41 finished with value: 0.75 and parameters: {'model_type': 'svm', 'C': 1.4640122900821786, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:53:29,249] Trial 42 finished with value: 0.731 and parameters: {'model_type': 'svm', 'C': 0.5114275112804929, 'kernel': 'rbf'}. Best is trial 26 with value: 0.754.
# [I 2024-12-15 10:53:58,366] Trial 43 finished with value: 0.758 and parameters: {'model_type': 'svm', 'C': 2.670539946780089, 'kernel': 'rbf'}. Best is trial 43 with value: 0.758.
# [I 2024-12-15 10:54:27,503] Trial 44 finished with value: 0.683 and parameters: {'model_type': 'svm', 'C': 4.001035312728787, 'kernel': 'linear'}. Best is trial 43 with value: 0.758.
# [I 2024-12-15 10:54:52,183] Trial 45 finished with value: 0.743 and parameters: {'model_type': 'svm', 'C': 0.1886579826593994, 'kernel': 'poly'}. Best is trial 43 with value: 0.758.
# [I 2024-12-15 10:55:21,546] Trial 46 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 10.96196449862552, 'kernel': 'rbf'}. Best is trial 43 with value: 0.758.
# [I 2024-12-15 10:55:22,897] Trial 47 finished with value: 0.714 and parameters: {'model_type': 'logistic_regression', 'C': 1.8293429263685481}. Best is trial 43 with value: 0.758.
# [I 2024-12-15 10:55:47,308] Trial 48 finished with value: 0.738 and parameters: {'model_type': 'svm', 'C': 0.005815591705049098, 'kernel': 'poly'}. Best is trial 43 with value: 0.758.
# [I 2024-12-15 10:56:16,790] Trial 49 finished with value: 0.751 and parameters: {'model_type': 'svm', 'C': 4.001512546032525, 'kernel': 'rbf'}. Best is trial 43 with value: 0.758.

# %%
# Output the best hyperparameters
print("Best trial:", study.best_trial)
print("Best hyperparameters:", study.best_params)
# Out:
# [I 2024-12-15 12:02:13,399] A new study created in memory with name: no-name-d0a9a9a4-e5d5-41b6-9d04-a26e9e550988
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-93703fe88b3e> in <cell line: 4>()
#       2
#       3 # Output the best hyperparameters
# ----> 4 print("Best trial:", study.best_trial)
#       5 print("Best hyperparameters:", study.best_params)
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/study.py in best_trial(self)
#     160             )
#     161
# --> 162         best_trial = self._storage.get_best_trial(self._study_id)
#     163
#     164         # If the trial with the best value is infeasible, select the best trial from all feasible
#
# /usr/local/lib/python3.10/dist-packages/optuna/storages/_in_memory.py in get_best_trial(self, study_id)
#     247
#     248             if best_trial_id is None:
# --> 249                 raise ValueError("No trials are completed yet.")
#     250             elif len(self._studies[study_id].directions) > 1:
#     251                 raise RuntimeError(
#
# ValueError: No trials are completed yet.

# %%
def train_best_model():
    params = study.best_params
    if params["model_type"] == "logistic_regression":
        best_model = LogisticRegression(C=params["C"], max_iter=1000, random_state=42)
    elif params["model_type"] == "svm":
        best_model = SVC(C=params["C"], kernel=params["kernel"], random_state=42)

    best_model.fit(X_train, y_train)
    return best_model

# %%
# Save the best model using pickle
def save_model(model, filename="best_model.pkl"):
    with open(filename, "wb") as file:
        pickle.dump(model, file)

# %%
# Load the model from a file
def load_model(filename="best_model.pkl"):
    with open(filename, "rb") as file:
        return pickle.load(file)

# %%
# Predict a single image
def predict_image(model, image_path):
    image = io.imread(image_path)
    image = transform.resize(image, (64, 64))
    feature = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), channel_axis=-1)
    feature = np.array(feature).reshape(1, -1)
    prediction = model.predict(feature)
    return "Cat" if prediction[0] == 0 else "Dog"

# %%
# Display model performance
def display_performance(model):
    y_pred = model.predict(X_test)
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

# %%
best_model = train_best_model()
save_model(best_model)

 # Load and evaluate the model
loaded_model = load_model()
display_performance(loaded_model)

# Predict a single image
image_path = ".jpg"  # Replace with an actual image path
prediction = predict_image(loaded_model, image_path)
print(f"Prediction for the image: {prediction}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       500
#            1       0.76      0.76      0.76       500
#
#     accuracy                           0.76      1000
#    macro avg       0.76      0.76      0.76      1000
# weighted avg       0.76      0.76      0.76      1000
#
# Prediction for the image: Cat

# %%
# !wget https://t4.ftcdn.net/jpg/02/66/72/41/360_F_266724172_Iy8gdKgMa7XmrhYYxLCxyhx6J7070Pr8.jpg
# Out:
# --2024-12-15 11:03:56--  https://t4.ftcdn.net/jpg/02/66/72/41/360_F_266724172_Iy8gdKgMa7XmrhYYxLCxyhx6J7070Pr8.jpg
# Resolving t4.ftcdn.net (t4.ftcdn.net)... 151.101.1.91, 151.101.65.91, 151.101.129.91, ...
# Connecting to t4.ftcdn.net (t4.ftcdn.net)|151.101.1.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41304 (40K) [image/jpeg]
# Saving to: ‘360_F_266724172_Iy8gdKgMa7XmrhYYxLCxyhx6J7070Pr8.jpg’
#
# 360_F_266724172_Iy8 100%[===================>]  40.34K  --.-KB/s    in 0.05s
#
# 2024-12-15 11:03:57 (820 KB/s) - ‘360_F_266724172_Iy8gdKgMa7XmrhYYxLCxyhx6J7070Pr8.jpg’ saved [41304/41304]
